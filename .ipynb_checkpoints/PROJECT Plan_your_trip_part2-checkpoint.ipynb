# %% [markdown]
# ### Scraping Hotels by City.

# %%
# !pip install plotly -q
# !pip install scrapy -q
#Importing libraries

# Install boto3 using pip 
## Add '!' only if you install directly from a Jupyter Notebook
# !pip install Boto3 -q

import requests
import pandas as pd
import requests
# Import os => Library used to easily manipulate operating systems
## More info => https://docs.python.org/3/library/os.html
import os 
# Import logging => Library used for logs manipulation 
## More info => https://docs.python.org/3/library/logging.html
import logging

# Import scrapy and scrapy.crawler 
import scrapy
from scrapy.crawler import CrawlerProcess
import re

import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as pyp
import plotly.io as pio
pd.options.display.max_columns = None
pio.renderers.default = "iframe_connected"

import boto3

# %% [markdown]
# #### Creating URLs to search for every city

# %%
# Cities 
desired_booking_searches = ["Mont Saint Michel","St Malo","Bayeux","Le Havre","Rouen","Paris","Amiens",
"Lille","Strasbourg","Chateau du Haut Koenigsbourg","Colmar","Eguisheim","Besancon","Dijon","Annecy","Grenoble","Lyon",
"Gorges du Verdon","Bormes les Mimosas","Cassis","Marseille","Aix en Provence","Avignon","Uzes","Nimes","Aigues Mortes",
"Saintes Maries de la mer","Collioure","Carcassonne","Toulouse","Montauban","Biarritz","Bayonne","La Rochelle"]


#desired_booking_searches.apply(lambda x :" ","+") 
desired_booking_searches2 = [] #These are the citie with a + replacing ' ' spaces to add it to the URL for requesting.
for string in desired_booking_searches:
    new_string = string.replace(" ", "+") 
    desired_booking_searches2.append(new_string)
print(desired_booking_searches2)
# Out:
# ['Mont+Saint+Michel', 'St+Malo', 'Bayeux', 'Le+Havre', 'Rouen', 'Paris', 'Amiens', 'Lille', 'Strasbourg', 'Chateau+du+Haut+Koenigsbourg', 'Colmar', 'Eguisheim', 'Besancon', 'Dijon', 'Annecy', 'Grenoble', 'Lyon', 'Gorges+du+Verdon', 'Bormes+les+Mimosas', 'Cassis', 'Marseille', 'Aix+en+Provence', 'Avignon', 'Uzes', 'Nimes', 'Aigues+Mortes', 'Saintes+Maries+de+la+mer', 'Collioure', 'Carcassonne', 'Toulouse', 'Montauban', 'Biarritz', 'Bayonne', 'La+Rochelle']

# %%
urls = [] #This list will contain all the Urls, for each city
for city in desired_booking_searches2:
    urls.append('https://www.booking.com/searchresults.fr.ss={}/'.format(city))

# %% [markdown]
# #### Creating scrapy spider

# %%
class booking_spider(scrapy.Spider):
    name = 'booking'
                                 
    # Starting URL
    start_urls = urls 

    def parse(self, response):

        for r in response.css('div.a1b3f50dcd.f7c6687c3d.a1f3ecff04.f996d8c258'):
            yield {
                'url': r.css('h3.a4225678b2 ::attr(href)').get(),
                'city' : r.css('span.f4bd0794db.b4273d69aa ::text').get(),
                'name' : r.css('h3.a4225678b2 ::text').get(),
                'note' : r.css('div.b5cd09854e.d10a6220b4::text').get(), 
                'coordinates': 'coordinates': text.css('a::attr(data-coords)').get(),
                'description': r.css('div.d8eab2cf7f ::text').get()
            }
                       
        try:
            next_page = response.css('a.bui-pagination__link.paging-next').attrib["href"] #Go to next page
        except KeyError: #No Href on the last page: raises KeyError
            logging.info('No next page. Terminating crawling process.')
        else:
            yield response.follow(next_page, callback=self.parse) #If there is a next page, get all the informations

# %%
# Name of the file where the results will be saved
filename = "hotels_info2.json"

# If file already exists, delete it before crawling (because Scrapy will concatenate the last and new results otherwise)
if filename in os.listdir('hotels/'):
        os.remove('hotels/' + filename)

# Declare a new CrawlerProcess with some settings
process = CrawlerProcess(settings = {
    'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:91.0) Gecko/20100101 Firefox/91.0',
    'LOG_LEVEL': logging.INFO,
    'AUTOTHROTTLE_ENABLED' : True,
    'AUTOTHROTTLE_START_DELAY' : 3,
    'AUTOTHROTTLE_MAX_DELAY' : 6,
    "FEEDS": {
        'hotels/' + filename : {"format": "json"},
    }
})

# Start the crawling using the spider you defined above
process.crawl(booking_spider)
process.start()
# Out:
# 2022-01-07 09:42:28 [scrapy.utils.log] INFO: Scrapy 2.5.1 started (bot: scrapybot)
# 2022-01-07 09:42:28 [scrapy.utils.log] INFO: Versions: lxml 4.7.1.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.8.6 | packaged by conda-forge | (default, Oct  7 2020, 19:08:05) - [GCC 7.5.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1h  22 Sep 2020), cryptography 3.1.1, Platform Linux-5.4.129+-x86_64-with-glibc2.10
# 2022-01-07 09:42:28 [scrapy.crawler] INFO: Overridden settings:
# {'AUTOTHROTTLE_ENABLED': True,
#  'AUTOTHROTTLE_MAX_DELAY': 6,
#  'AUTOTHROTTLE_START_DELAY': 3,
#  'LOG_LEVEL': 20,
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:91.0) '
#                'Gecko/20100101 Firefox/91.0'}
# 2022-01-07 09:42:28 [scrapy.extensions.telnet] INFO: Telnet Password: d83770e3f7bdfc7d
# 2022-01-07 09:42:28 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.throttle.AutoThrottle']
# 2022-01-07 09:42:28 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-01-07 09:42:28 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-01-07 09:42:28 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-01-07 09:42:28 [scrapy.core.engine] INFO: Spider opened
# 2022-01-07 09:42:28 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-01-07 09:42:28 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-01-07 09:43:26 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:28 [scrapy.extensions.logstats] INFO: Crawled 1 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2022-01-07 09:43:30 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:32 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:34 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:35 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:36 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:37 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:37 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:38 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:39 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:39 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:39 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:40 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:40 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:41 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:42 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:51 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:52 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:53 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:53 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:54 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:54 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:55 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:56 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:56 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:56 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:57 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:58 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:58 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:43:59 [root] INFO: No next page. Terminating crawling process.
# 2022-01-07 09:44:01 [scrapy.downloadermiddlewares.retry] ERROR: Gave up retrying <GET https://www.booking.com/searchresults.fr.ss=Montauban> (failed 3 times): 429 Unknown Status
# 2022-01-07 09:44:01 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <429 https://www.booking.com/searchresults.fr.ss=Montauban>: HTTP status code is not handled or not allowed
# 2022-01-07 09:44:02 [scrapy.downloadermiddlewares.retry] ERROR: Gave up retrying <GET https://www.booking.com/searchresults.fr.ss=Biarritz> (failed 3 times): 429 Unknown Status
# 2022-01-07 09:44:02 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <429 https://www.booking.com/searchresults.fr.ss=Biarritz>: HTTP status code is not handled or not allowed
# 2022-01-07 09:44:04 [scrapy.downloadermiddlewares.retry] ERROR: Gave up retrying <GET https://www.booking.com/searchresults.fr.ss=Bayonne> (failed 3 times): 429 Unknown Status
# 2022-01-07 09:44:04 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <429 https://www.booking.com/searchresults.fr.ss=Bayonne>: HTTP status code is not handled or not allowed
# 2022-01-07 09:44:04 [scrapy.downloadermiddlewares.retry] ERROR: Gave up retrying <GET https://www.booking.com/searchresults.fr.ss=La+Rochelle> (failed 3 times): 429 Unknown Status
# 2022-01-07 09:44:04 [scrapy.spidermiddlewares.httperror] INFO: Ignoring response <429 https://www.booking.com/searchresults.fr.ss=La+Rochelle>: HTTP status code is not handled or not allowed
# 2022-01-07 09:44:04 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-01-07 09:44:04 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 52711,
#  'downloader/request_count': 72,
#  'downloader/request_method_count/GET': 72,
#  'downloader/response_bytes': 5283260,
#  'downloader/response_count': 72,
#  'downloader/response_status_count/200': 30,
#  'downloader/response_status_count/301': 30,
#  'downloader/response_status_count/429': 12,
#  'elapsed_time_seconds': 95.921853,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 1, 7, 9, 44, 4, 687311),
#  'httpcompression/response_bytes': 32100048,
#  'httpcompression/response_count': 30,
#  'httperror/response_ignored_count': 4,
#  'httperror/response_ignored_status_count/429': 4,
#  'log_count/ERROR': 4,
#  'log_count/INFO': 45,
#  'memusage/max': 154091520,
#  'memusage/startup': 141824000,
#  'response_received_count': 34,
#  'retry/count': 8,
#  'retry/max_reached': 4,
#  'retry/reason_count/429 Unknown Status': 8,
#  'scheduler/dequeued': 72,
#  'scheduler/dequeued/memory': 72,
#  'scheduler/enqueued': 72,
#  'scheduler/enqueued/memory': 72,
#  'start_time': datetime.datetime(2022, 1, 7, 9, 42, 28, 765458)}
# 2022-01-07 09:44:04 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
hotels = pd.read_json('hotels/hotels_info_final.json')
hotels.head(10)
# Out:
#                                                  url  \
# 0  https://www.booking.com/hotel/fr/vert.en-gb.ht...
# 1  https://www.booking.com/hotel/fr/mont-saint-mi...
# 2  https://www.booking.com/hotel/fr/de-la-digue.e...
# 3  https://www.booking.com/hotel/fr/hotel-saint-a...
# 4  https://www.booking.com/hotel/fr/hotel-gabriel...
# 5  https://www.booking.com/hotel/fr/les-terrasses...
# 6  https://www.booking.com/hotel/fr/la-vieille-au...
# 7  https://www.booking.com/hotel/fr/le-relais-sai...
# 8  https://www.booking.com/hotel/fr/camping-aux-p...
# 9  https://www.booking.com/hotel/fr/le-mouton-bla...
#
#                                                 city  \
# 0  https://www.booking.com/searchresults.html?si=...
# 1  https://www.booking.com/searchresults.html?si=...
# 2  https://www.booking.com/searchresults.html?si=...
# 3  https://www.booking.com/searchresults.html?si=...
# 4  https://www.booking.com/searchresults.html?si=...
# 5  https://www.booking.com/searchresults.html?si=...
# 6  https://www.booking.com/searchresults.html?si=...
# 7  https://www.booking.com/searchresults.html?si=...
# 8  https://www.booking.com/searchresults.html?si=...
# 9  https://www.booking.com/searchresults.html?si=...
#
#                                 name  note  \
# 0                     \nHôtel Vert\n   8.1
# 1      \nMercure Mont Saint Michel\n   8.2
# 2              \nHotel De La Digue\n   7.1
# 3                \nLe Saint Aubert\n   7.3
# 4                  \nHotel Gabriel\n   8.1
# 5          \nLes Terrasses Poulard\n   7.3
# 6             \nLa Vieille Auberge\n   7.4
# 7         \nLe Relais Saint Michel\n   7.8
# 8  \nCAMPING AUX POMMIERS - TOHAPI\n   8.3
# 9                \nLe Mouton Blanc\n   7.2
#
#                           coordinates  \
# 0  -1.50961697101593,48.6147004862904
# 1  -1.51054501533508,48.6142465295929
# 2  -1.51091784238815,48.6168815494412
# 3  -1.51010513305664,48.6129378347065
# 4   -1.5107099711895,48.6153814136834
# 5  -1.51037871837616,48.6353494256412
# 6                 -1.511457,48.636063
# 7  -1.51039615273476,48.6175872716489
# 8                   -1.5101,48.613555
# 9  -1.50989592075348,48.6360229844471
#
#                                          description
# 0  \nHotel Vert offers pastel-coloured rooms with...
# 1  \nThis Mercure is situated in parkland just 2 ...
# 2  \nThe traditional Hotel De La Digue in the Bas...
# 3  \nSet amid lush greenery, just 2 km from the M...
# 4  \nHotel Gabriel is located 1.6 Km from Mont Sa...
# 5  \nComposed of 2 different buildings, Les Terra...
# 6  \nLa Vieille Auberge is located in the medieva...
# 7  \nLe Relais Saint Michel is an hotel facing th...
# 8  \nSet in Le Mont Saint Michel in the Lower Nor...
# 9  \nAt the foot of the abbey, the Mouton Blanc H...

# %% [markdown]
# #### Cleaning data

# %%
#Cleaning text
hotels['name'] = hotels['name'].str.replace('\n' , '')
hotels['description'].str.replace('\n' , '') #Clean html characters

#Separating latitude and longitude infos
hotels[['latitude','longitude']] = hotels["coordinates"].str.split(',', expand=True)

# %%
#Getting cities names from link, with the initial names from "desired_booking_searches" list
hotels['city'] = hotels['city'].apply(lambda x: x.replace("https://www.booking.com/searchresults.html?si=ai%2Cco%2Cci%2Cre%2Cla%2Cdi;ss=searchresults.fr.ss=", 
                                                          ""))

hotels['city'] = hotels['city'].apply(lambda x: x.split(";", 1)) #City name will be at indew 0
hotels['city'] = hotels['city'].apply(lambda x: x[0]) #extracting city name
hotels['city'] = hotels['city'].str.replace("+"," ") #Getting rid of the + sign

# %%
hotels
# Out:
#                                                    url                  city  \
# 0    https://www.booking.com/hotel/fr/vert.en-gb.ht...  Le Mont Saint Michel
# 1    https://www.booking.com/hotel/fr/mont-saint-mi...  Le Mont Saint Michel
# 2    https://www.booking.com/hotel/fr/de-la-digue.e...  Le Mont Saint Michel
# 3    https://www.booking.com/hotel/fr/hotel-saint-a...  Le Mont Saint Michel
# 4    https://www.booking.com/hotel/fr/hotel-gabriel...  Le Mont Saint Michel
# ..                                                 ...                   ...
# 728  https://www.booking.com/hotel/fr/de-paris-la-r...           La Rochelle
# 729  https://www.booking.com/hotel/fr/de-la-paix-la...           La Rochelle
# 730  https://www.booking.com/hotel/fr/le-rupella.en...           La Rochelle
# 731  https://www.booking.com/hotel/fr/masqhotel.en-...           La Rochelle
# 732  https://www.booking.com/hotel/fr/le-yachtman.e...           La Rochelle
#
#                                name  note                         coordinates  \
# 0                        Hôtel Vert   8.1  -1.50961697101593,48.6147004862904
# 1         Mercure Mont Saint Michel   8.2  -1.51054501533508,48.6142465295929
# 2                 Hotel De La Digue   7.1  -1.51091784238815,48.6168815494412
# 3                   Le Saint Aubert   7.3  -1.51010513305664,48.6129378347065
# 4                     Hotel Gabriel   8.1   -1.5107099711895,48.6153814136834
# ..                              ...   ...                                 ...
# 728                  Hotel de Paris   7.9  -1.15117460489273,46.1619691141879
# 729                Hotel de La Paix   8.0   -1.15085542169254,46.161939390064
# 730                Hôtel Le Rupella   7.2  -1.15106999874115,46.1581749442479
# 731  Best Western Premier Masqhotel   8.6  -1.14505648612976,46.1548367218857
# 732               Hôtel Le Yachtman   7.6  -1.14996761083603,46.1572836509306
#
#                                            description           latitude  \
# 0    \nHotel Vert offers pastel-coloured rooms with...  -1.50961697101593
# 1    \nThis Mercure is situated in parkland just 2 ...  -1.51054501533508
# 2    \nThe traditional Hotel De La Digue in the Bas...  -1.51091784238815
# 3    \nSet amid lush greenery, just 2 km from the M...  -1.51010513305664
# 4    \nHotel Gabriel is located 1.6 Km from Mont Sa...   -1.5107099711895
# ..                                                 ...                ...
# 728  \nThe Hotel de Paris is located in the city ce...  -1.15117460489273
# 729  \nLocated in the heart of the city and footste...  -1.15085542169254
# 730  \nLocated in the heart of La Rochelle, just a ...  -1.15106999874115
# 731  \nThe Best Western Masqhotel is a design hotel...  -1.14505648612976
# 732  \nLocated in La Rochelle, Le Yachtman features...  -1.14996761083603
#
#             longitude
# 0    48.6147004862904
# 1    48.6142465295929
# 2    48.6168815494412
# 3    48.6129378347065
# 4    48.6153814136834
# ..                ...
# 728  46.1619691141879
# 729   46.161939390064
# 730  46.1581749442479
# 731  46.1548367218857
# 732  46.1572836509306
#
# [733 rows x 8 columns]

# %%
hotels.drop('coordinates', axis = 1, inplace =True)

# %%
hotels
# Out:
#                                                    url                  city  \
# 0    https://www.booking.com/hotel/fr/vert.en-gb.ht...  Le Mont Saint Michel
# 1    https://www.booking.com/hotel/fr/mont-saint-mi...  Le Mont Saint Michel
# 2    https://www.booking.com/hotel/fr/de-la-digue.e...  Le Mont Saint Michel
# 3    https://www.booking.com/hotel/fr/hotel-saint-a...  Le Mont Saint Michel
# 4    https://www.booking.com/hotel/fr/hotel-gabriel...  Le Mont Saint Michel
# ..                                                 ...                   ...
# 728  https://www.booking.com/hotel/fr/de-paris-la-r...           La Rochelle
# 729  https://www.booking.com/hotel/fr/de-la-paix-la...           La Rochelle
# 730  https://www.booking.com/hotel/fr/le-rupella.en...           La Rochelle
# 731  https://www.booking.com/hotel/fr/masqhotel.en-...           La Rochelle
# 732  https://www.booking.com/hotel/fr/le-yachtman.e...           La Rochelle
#
#                                name  note  \
# 0                        Hôtel Vert   8.1
# 1         Mercure Mont Saint Michel   8.2
# 2                 Hotel De La Digue   7.1
# 3                   Le Saint Aubert   7.3
# 4                     Hotel Gabriel   8.1
# ..                              ...   ...
# 728                  Hotel de Paris   7.9
# 729                Hotel de La Paix   8.0
# 730                Hôtel Le Rupella   7.2
# 731  Best Western Premier Masqhotel   8.6
# 732               Hôtel Le Yachtman   7.6
#
#                                            description           latitude  \
# 0    \nHotel Vert offers pastel-coloured rooms with...  -1.50961697101593
# 1    \nThis Mercure is situated in parkland just 2 ...  -1.51054501533508
# 2    \nThe traditional Hotel De La Digue in the Bas...  -1.51091784238815
# 3    \nSet amid lush greenery, just 2 km from the M...  -1.51010513305664
# 4    \nHotel Gabriel is located 1.6 Km from Mont Sa...   -1.5107099711895
# ..                                                 ...                ...
# 728  \nThe Hotel de Paris is located in the city ce...  -1.15117460489273
# 729  \nLocated in the heart of the city and footste...  -1.15085542169254
# 730  \nLocated in the heart of La Rochelle, just a ...  -1.15106999874115
# 731  \nThe Best Western Masqhotel is a design hotel...  -1.14505648612976
# 732  \nLocated in La Rochelle, Le Yachtman features...  -1.14996761083603
#
#             longitude
# 0    48.6147004862904
# 1    48.6142465295929
# 2    48.6168815494412
# 3    48.6129378347065
# 4    48.6153814136834
# ..                ...
# 728  46.1619691141879
# 729   46.161939390064
# 730  46.1581749442479
# 731  46.1548367218857
# 732  46.1572836509306
#
# [733 rows x 7 columns]

# %%
hotels.to_csv('hotels_info.csv')

# %% [markdown]
# #### Visualizing data

# %%
weather = pd.read_csv('cities_weather.csv')
hotels = pd.read_csv('hotels_info.csv')

# %%
weather
# Out:
#      id             Cities   Latitude  Longitude  day   dtf    ntf  \
# 0     1  Mont Saint Michel  48.635954  -1.511460    0  6.89   8.65
# 1     1  Mont Saint Michel  48.635954  -1.511460    1  9.77   6.61
# 2     1  Mont Saint Michel  48.635954  -1.511460    2  8.21   8.43
# 3     1  Mont Saint Michel  48.635954  -1.511460    3  9.39   7.56
# 4     1  Mont Saint Michel  48.635954  -1.511460    4  6.03   2.85
# ..   ..                ...        ...        ...  ...   ...    ...
# 233  34        La Rochelle  46.159113  -1.152043    2  9.64  10.02
# 234  34        La Rochelle  46.159113  -1.152043    3  9.59   8.86
# 235  34        La Rochelle  46.159113  -1.152043    4  6.44   3.82
# 236  34        La Rochelle  46.159113  -1.152043    5  5.92   3.60
# 237  34        La Rochelle  46.159113  -1.152043    6  3.56   2.98
#
#                        wf
# 0           moderate rain
# 1    heavy intensity rain
# 2              light rain
# 3         overcast clouds
# 4        scattered clouds
# ..                    ...
# 233         moderate rain
# 234            light rain
# 235             clear sky
# 236         broken clouds
# 237             clear sky
#
# [238 rows x 8 columns]

# %%
weather_map = px.scatter_geo(
    lon = weather['Longitude'],
    lat=weather["Latitude"],
    color= weather['dtf'], #day temperature
    animation_frame = weather['day']
)
#To get display informations, we could have chosen SIZE for day time forecast and COLOR for wf = weather description but as there are negative values in dtf, SIZE would show an error

weather_map.update_layout(
    title = 'Weather forecast by City',
    geo_scope = 'europe'
)

weather_map.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_389.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
hotels.drop('Unnamed: 0',axis = 1, inplace = True)

# %%
hotels
# Out:
#                                                    url                  city  \
# 0    https://www.booking.com/hotel/fr/vert.en-gb.ht...  Le Mont Saint Michel
# 1    https://www.booking.com/hotel/fr/mont-saint-mi...  Le Mont Saint Michel
# 2    https://www.booking.com/hotel/fr/de-la-digue.e...  Le Mont Saint Michel
# 3    https://www.booking.com/hotel/fr/hotel-saint-a...  Le Mont Saint Michel
# 4    https://www.booking.com/hotel/fr/hotel-gabriel...  Le Mont Saint Michel
# ..                                                 ...                   ...
# 728  https://www.booking.com/hotel/fr/de-paris-la-r...           La Rochelle
# 729  https://www.booking.com/hotel/fr/de-la-paix-la...           La Rochelle
# 730  https://www.booking.com/hotel/fr/le-rupella.en...           La Rochelle
# 731  https://www.booking.com/hotel/fr/masqhotel.en-...           La Rochelle
# 732  https://www.booking.com/hotel/fr/le-yachtman.e...           La Rochelle
#
#                                name  note  \
# 0                        Hôtel Vert   8.1
# 1         Mercure Mont Saint Michel   8.2
# 2                 Hotel De La Digue   7.1
# 3                   Le Saint Aubert   7.3
# 4                     Hotel Gabriel   8.1
# ..                              ...   ...
# 728                  Hotel de Paris   7.9
# 729                Hotel de La Paix   8.0
# 730                Hôtel Le Rupella   7.2
# 731  Best Western Premier Masqhotel   8.6
# 732               Hôtel Le Yachtman   7.6
#
#                                            description  latitude  longitude
# 0    \nHotel Vert offers pastel-coloured rooms with... -1.509617  48.614700
# 1    \nThis Mercure is situated in parkland just 2 ... -1.510545  48.614247
# 2    \nThe traditional Hotel De La Digue in the Bas... -1.510918  48.616882
# 3    \nSet amid lush greenery, just 2 km from the M... -1.510105  48.612938
# 4    \nHotel Gabriel is located 1.6 Km from Mont Sa... -1.510710  48.615381
# ..                                                 ...       ...        ...
# 728  \nThe Hotel de Paris is located in the city ce... -1.151175  46.161969
# 729  \nLocated in the heart of the city and footste... -1.150855  46.161939
# 730  \nLocated in the heart of La Rochelle, just a ... -1.151070  46.158175
# 731  \nThe Best Western Masqhotel is a design hotel... -1.145056  46.154837
# 732  \nLocated in La Rochelle, Le Yachtman features... -1.149968  46.157284
#
# [733 rows x 7 columns]

# %%
for city in desired_booking_searches: #iterate in cities list
    hotels['city'].loc[hotels['city'].str.contains(city) == True] = city #changing cities names
# Out:
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2022-01-07 14:53:54 [py.warnings] WARNING: /opt/conda/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 733 entries, 0 to 732
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   url          733 non-null    object
#  1   city         733 non-null    object
#  2   name         733 non-null    object
#  3   note         644 non-null    float64
#  4   description  733 non-null    object
#  5   latitude     733 non-null    float64
#  6   longitude    733 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 40.2+ KB

# %%
hotels['note'] = hotels['note'].fillna('0') #Getting rid of na values in note column
hotels['note'] = hotels['note'].astype('float')

# %%
fig = px.scatter_mapbox(hotels, lat="longitude", lon="latitude", 
                        color="note", 
                        mapbox_style="carto-positron", 
                        zoom=4, hover_name='name', size_max=8)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_395.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
top_hotels = hotels.groupby('city').apply(lambda x : x.sort_values(by = 'note', ascending = False).head(5))
top_hotels.rename(columns={'city':'Cities'}) #So it doesn't confuse us with the index 'city'
# Out:
#                                                                  url  \
# city
# Aigues Mortes 548  https://www.booking.com/hotel/fr/au-coeur-des-...
#               543  https://www.booking.com/hotel/fr/la-maison-did...
#               549  https://www.booking.com/hotel/fr/les-remparts-...
#               542  https://www.booking.com/hotel/fr/la-maison-de-...
#               538  https://www.booking.com/hotel/fr/42-rue-pasteu...
# ...                                                              ...
# Uzes          485  https://www.booking.com/hotel/fr/bon-jour-uzes...
#               488  https://www.booking.com/hotel/fr/maison-theodo...
#               489  https://www.booking.com/hotel/fr/l-39-albiouss...
#               480  https://www.booking.com/hotel/fr/terrasses-uze...
#               500  https://www.booking.com/hotel/fr/apartment-sig...
#
#                           Cities                               name  note  \
# city
# Aigues Mortes 548  Aigues Mortes               Au Cœur des Remparts   9.9
#               543  Aigues Mortes                  La Maison Diderot   9.8
#               549  Aigues Mortes  Boutique Hôtel des Remparts & Spa   9.6
#               542  Aigues Mortes           La Maison de la Viguerie   9.5
#               538  Aigues Mortes                     42 Rue Pasteur   9.5
# ...                          ...                                ...   ...
# Uzes          485           Uzes                      Bon Jour Uzès   9.8
#               488           Uzes                   Maison Theodorit   9.7
#               489           Uzes                        L'Albiousse   9.7
#               480           Uzes                      Les Terrasses   9.7
#               500           Uzes                  Apartment Sigalon   9.6
#
#                                                          description  \
# city
# Aigues Mortes 548  \nOffering free WiFi and city views, Au Cœur d...
#               543  \nLocated in Aigues-Mortes, 44 km from Nîmes, ...
#               549  \nLocated in a former military station dating ...
#               542  \nSituated inside the medieval city walls of A...
#               538  \nOffering free WiFi and city views, 42 Rue Pa...
# ...                                                              ...
# Uzes          485  \nBon Jour Uzès is situated in Uzès. The prope...
#               488  \nMaison Theodorit is located in Uzès. The air...
#               489  \nSituated in Uzès, 32 km from Alès, L'Albious...
#               480  \nSituated in Uzès, 43 km from Vallon-Pont-dʼA...
#               500  \nSituated in Uzès, Apartment Sigalon features...
#
#                    latitude  longitude
# city
# Aigues Mortes 548  4.192973  43.565401
#               543  4.194281  43.566736
#               549  4.190344  43.568036
#               542  4.192948  43.565900
#               538  4.192579  43.566075
# ...                     ...        ...
# Uzes          485  4.419075  44.011972
#               488  4.421346  44.011877
#               489  4.421124  44.012720
#               480  4.420584  44.012017
#               500  4.419659  44.013803
#
# [145 rows x 7 columns]

# %%
fig = px.scatter_mapbox(top_hotels, #These are the top 5 best hotels 
                        lat="longitude", 
                        lon="latitude", 
                        color="note",
                        size = 'note',
                        mapbox_style="carto-positron", 
                        zoom=4, hover_name='name', size_max=8,
                       title = "Top 5 best hotels for every city")

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_402.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# #### Merging dataframes

# %%
#Merging on Cities columns
hotels.rename(columns={'city':'Cities'},inplace =True)
weather_hotels = weather.merge(hotels, on='Cities')

# %%
weather_hotels
# Out:
#       id             Cities   Latitude  Longitude  day   dtf   ntf  \
# 0      1  Mont Saint Michel  48.635954  -1.511460    0  6.89  8.65
# 1      1  Mont Saint Michel  48.635954  -1.511460    0  6.89  8.65
# 2      1  Mont Saint Michel  48.635954  -1.511460    0  6.89  8.65
# 3      1  Mont Saint Michel  48.635954  -1.511460    0  6.89  8.65
# 4      1  Mont Saint Michel  48.635954  -1.511460    0  6.89  8.65
# ...   ..                ...        ...        ...  ...   ...   ...
# 5126  34        La Rochelle  46.159113  -1.152043    6  3.56  2.98
# 5127  34        La Rochelle  46.159113  -1.152043    6  3.56  2.98
# 5128  34        La Rochelle  46.159113  -1.152043    6  3.56  2.98
# 5129  34        La Rochelle  46.159113  -1.152043    6  3.56  2.98
# 5130  34        La Rochelle  46.159113  -1.152043    6  3.56  2.98
#
#                  wf                                                url  \
# 0     moderate rain  https://www.booking.com/hotel/fr/vert.en-gb.ht...
# 1     moderate rain  https://www.booking.com/hotel/fr/mont-saint-mi...
# 2     moderate rain  https://www.booking.com/hotel/fr/de-la-digue.e...
# 3     moderate rain  https://www.booking.com/hotel/fr/hotel-saint-a...
# 4     moderate rain  https://www.booking.com/hotel/fr/hotel-gabriel...
# ...             ...                                                ...
# 5126      clear sky  https://www.booking.com/hotel/fr/de-paris-la-r...
# 5127      clear sky  https://www.booking.com/hotel/fr/de-la-paix-la...
# 5128      clear sky  https://www.booking.com/hotel/fr/le-rupella.en...
# 5129      clear sky  https://www.booking.com/hotel/fr/masqhotel.en-...
# 5130      clear sky  https://www.booking.com/hotel/fr/le-yachtman.e...
#
#                                 name  note  \
# 0                         Hôtel Vert   8.1
# 1          Mercure Mont Saint Michel   8.2
# 2                  Hotel De La Digue   7.1
# 3                    Le Saint Aubert   7.3
# 4                      Hotel Gabriel   8.1
# ...                              ...   ...
# 5126                  Hotel de Paris   7.9
# 5127                Hotel de La Paix   8.0
# 5128                Hôtel Le Rupella   7.2
# 5129  Best Western Premier Masqhotel   8.6
# 5130               Hôtel Le Yachtman   7.6
#
#                                             description  latitude  longitude
# 0     \nHotel Vert offers pastel-coloured rooms with... -1.509617  48.614700
# 1     \nThis Mercure is situated in parkland just 2 ... -1.510545  48.614247
# 2     \nThe traditional Hotel De La Digue in the Bas... -1.510918  48.616882
# 3     \nSet amid lush greenery, just 2 km from the M... -1.510105  48.612938
# 4     \nHotel Gabriel is located 1.6 Km from Mont Sa... -1.510710  48.615381
# ...                                                 ...       ...        ...
# 5126  \nThe Hotel de Paris is located in the city ce... -1.151175  46.161969
# 5127  \nLocated in the heart of the city and footste... -1.150855  46.161939
# 5128  \nLocated in the heart of La Rochelle, just a ... -1.151070  46.158175
# 5129  \nThe Best Western Masqhotel is a design hotel... -1.145056  46.154837
# 5130  \nLocated in La Rochelle, Le Yachtman features... -1.149968  46.157284
#
# [5131 rows x 14 columns]

# %%
weather_hotels.to_csv('weather_hotels.csv') #Exporting the final dataframe

# %% [markdown]
# ### Uploading the final dataframe to a S3 bucket

# %%
credentials = pd.read_csv('aws_credentials.csv')
session = boto3.Session(aws_access_key_id=credentials.accesskeyid, 
                        aws_secret_access_key=credentials.secretaccesskey)

s3 = session.resource("s3")

bucket = s3.create_bucket(Bucket="bucket-from-kayak-project-pierreka")

put_object = bucket.put_object(Key="weather_hotels.csv", Body=csv)
